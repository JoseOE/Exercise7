# %% [markdown]
# Se entrevistó a 30 personas para que indicaran cuál es su equipo de futbol preferido. Los
# resultados fueron los siguientes:

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# <a id="Distribucion de Frecuencias"></a>
# ##  Distribucion de Frecuencias...
#
# <table>
# <thead>
# <tr>
# <th>EQUIPO</th>
# <th>FRECUENCIA</th>
# <th>FRECUENCIAS RELATIVA</th>
# <th>FRECUANCIAS ACUMULADA</th>
#
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>Pumas</td>
# <td>8</td>
# <td>26.67%</td>
# <td>26.67%</td>
#
# </tr>
# <tr>
# <td>Chivas</td>
# <td>5</td>
# <td>16.67%</td>
# <td>43.33%</td>
#
# </tr>
# <tr>
# <td>Santos</td>
# <td>3</td>
# <td>10.00%</td>
# <td>53.33%</td>
#
# </tr>
# <tr>
# <td>America</td>
# <td>8</td>
# <td>26.67%</td>
# <td>80.00%</td></tr>
# <tr>
# <td>Toluca</td>
# <td>4</td>
# <td>13.33%</td>
# <td>93.33%</td>
#
# </tr>
#
# <tr>
# <td>Necaxa</td>
# <td>2</td>
# <td>6.67%</td>
# <td>100.00%</td>
#
# </tr>
# </tbody>
# </table>

# %%
# Barras Valeria
marcas_clases=[1, 2, 3, 4, 5, 6]
frecuencias=[8, 5, 3, 8, 4, 2]
marcas_texto=["Pumas", "Chivas", "Santos", "America", "Toluca", "Necaxa"]
plt.figure(figsize = (12, 6))
plt.barh(marcas_clases, frecuencias, 
        height = 0.75, edgecolor = "k",
       color = ["#eb445b", "#f5938b", "#f0cdab", "#f1e7c5", "#CD617D", "#b6d4bb"])
plt.yticks(marcas_clases, marcas_texto, fontsize = 15)
plt.xlabel("Marcas de clase", fontsize = 20)
plt.ylabel("Frecuencias", fontsize = 20)
plt.title("Diagrama de Barras", fontsize = 25)
#plt.grid()
plt.show()

# %%
datos = [26.67 , 16.67, 10, 26.67, 13.33, 6.66]
marcas_texto = ["Pumas", "Chivas", "Santos", "América", "Toluca", "Necaxa"]
separaciones = [0.2, 0, 0, 0.2, 0, 0]

plt.pie(datos, 
       explode = separaciones, 
       counterclock = False, 
       startangle = 90, 
       autopct = "%0.1f%%", 
       pctdistance = 0.8, 
       colors = ['#e4e6c9', '#e6dac6', '#d6c3b9', '#c2b48a', '#b37883', '#cdc7b5'], 
       labels = marcas_texto)
plt.show()
